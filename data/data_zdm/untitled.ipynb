# %%
#  nohup sshpass -p 'ruc2025' scp -rp -P 33777 chengxin@ssh-cn-huabei1.ebcloud.com:/home/chengxin/chengxin/vasflow/data/data_zdm ./data &
#  python data/check_meta.py --path  data/data_zdm

# %%
import csv
from glob import glob
from tqdm import tqdm

split = 'train'
filename = 'train_25_gtref_V2C.csv'
savename = 'train_25_gtref_V2C.csv'


data = []
with open(filename, 'r') as csvfile:
    csv_reader = csv.reader(csvfile, delimiter='|')
    for row in csv_reader:
        data.append(row)

len(data)
# Out:
# 343889

# %%
# # 88
for i in tqdm(range(len(data))):
    for j in range(len(row)-2):
        assert ('/home/chengxin/chengxin/dataset' in data[i][j]) or ('/home/chengxin/chengxin/dataset/Dataset_feature/' in data[i][j])
        data[i][j] = data[i][j].replace('/home/chengxin/chengxin/dataset/Dataset_feature/', '/home/chengxin/chengxin/Dataset_feature/')
        data[i][j] = data[i][j].replace('/home/chengxin/chengxin/dataset/', '/home/chengxin/chengxin/Dataset_Sound/')

        if 'VGGSound' in data[i][j]:
            data[i][j] = f"/home/chengxin/chengxin/Dataset_Sound/VGGSound/dataset/{split}/10/{data[i][j].split('/')[-1]}"
# Out:
# 100%|██████████| 8629/8629 [00:00<00:00, 233209.08it/s]

# %%
# # 87
# for i in tqdm(range(len(data))):
#     for j in range(len(row)-2):
#         assert ('/home/chengxin/chengxin/Dataset_Sound/' in data[i][j]) or ('/home/chengxin/chengxin/Dataset_feature/' in data[i][j])
#         data[i][j] = data[i][j].replace('/home/chengxin/chengxin/Dataset_feature/', '/data-88-02/chengxin/Dataset_feature/')
#         data[i][j] = data[i][j].replace('/home/chengxin/chengxin/Dataset_Sound/', '/data-03/chengxin/Dataset_Sound/')

#         # if 'VGGSound' in data[i][j]:
#         #     data[i][j] = f"/home/chengxin/chengxin/Dataset_Sound/VGGSound/dataset/{split}/10/{data[i][j].split('/')[-1]}"
# Out:
# ...
# 100%|██████████| 19976/19976 [00:00<00:00, 241157.69it/s]

# %%
with open(savename, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f, delimiter = '|')        # 默认逗号分隔
    writer.writerows(data)

# %%
import csv
from glob import glob
from tqdm import tqdm

filename  = 'test_25_randref_Chem_LRS2_GRID_VGG.csv'
filename2 = 'test_25_randref_V2C.csv'
savename =  'test_25_randref_Chem_LRS2_GRID_VGG_V2C.csv'


data1 = []
with open(filename, 'r') as csvfile:
    csv_reader = csv.reader(csvfile, delimiter='|')
    for row in csv_reader:
        data1.append(row)

with open(filename2, 'r') as csvfile:
    csv_reader = csv.reader(csvfile, delimiter='|')
    for row in csv_reader:
        data1.append(row)


with open(savename, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f, delimiter = '|')        # 默认逗号分隔
    writer.writerows(data1)

len(data1)
# Out:
# 20770

# %%
import csv
from glob import glob
from tqdm import tqdm

split = 'test'
filename = 'test_25_randref_Chem_LRS2_GRID_VGG.csv'
savename = 'test_25_randref_VGG.csv'


data = []
with open(filename, 'r') as csvfile:
    csv_reader = csv.reader(csvfile, delimiter='|')
    for row in csv_reader:
        data.append(row)
print(len(data))



# # 88
new_data = []
for i in tqdm(range(len(data))):
    # # # if '@' not in data[i][0]:
    # # #     new_data.append(data[i])
    if 'VGGSound' in data[i][0]:
        # continue                     # VTTS
        new_data.append(data[i])       # V2A
    else:
        continue                     # V2A
        # new_data.append(data[i])     # VTTS
len(new_data)
# Out:
# 19451
# 100%|██████████| 19451/19451 [00:00<00:00, 3114821.59it/s]
# 15263

# %%
with open(savename, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f, delimiter = '|')        # 默认逗号分隔
    writer.writerows(new_data)
